# %% [markdown]
# # Airthmetic Operations with pandas:

# %%
import pandas as pd

# %%
air = pd.DataFrame({"v1":[1,2,3,4,5],"v2":[6,7,8,9,10]})
air
# Out:
#    v1  v2
# 0   1   6
# 1   2   7
# 2   3   8
# 3   4   9
# 4   5  10

# %%
air["Sum"]=air["v1"] + air["v2"] #air["Sum"] is a new column for the air variable where all the sum value of air[v1],air[v2] 
# will store

# %%
air
# Out:
#    v1  v2  Sum
# 0   1   6    7
# 1   2   7    9
# 2   3   8   11
# 3   4   9   13
# 4   5  10   15

# %%
air["mul"]=air["v1"]*air["v2"]
air
# Out:
#    v1  v2  Sum  mul
# 0   1   6    7    6
# 1   2   7    9   14
# 2   3   8   11   24
# 3   4   9   13   36
# 4   5  10   15   50

# %%
air["div"]=air["v1"]/air["v2"]
air
# Out:
#    v1  v2  Sum  mul       div
# 0   1   6    7    6  0.166667
# 1   2   7    9   14  0.285714
# 2   3   8   11   24  0.375000
# 3   4   9   13   36  0.444444
# 4   5  10   15   50  0.500000

# %%
air["Sub"]=air["v1"]-air["v2"]
air
# Out:
#    v1  v2  Sum  mul       div  Sub
# 0   1   6    7    6  0.166667   -5
# 1   2   7    9   14  0.285714   -5
# 2   3   8   11   24  0.375000   -5
# 3   4   9   13   36  0.444444   -5
# 4   5  10   15   50  0.500000   -5

# %%
var = pd.DataFrame({"a":[10,20,15,17,25],"b":[25,18,6,11,38]})
var
# Out:
#     a   b
# 0  10  25
# 1  20  18
# 2  15   6
# 3  17  11
# 4  25  38

# %%
var["ans"] = var["a"] <=20
var[["a","ans"]] # [[]] are use to fetch the select columns:
# Out:
#     a    ans
# 0  10   True
# 1  20   True
# 2  15   True
# 3  17   True
# 4  25  False

# %%
var["ans"] = var["b"] >= 20
var[["b","ans"]]
# Out:
#     b    ans
# 0  25   True
# 1  18  False
# 2   6  False
# 3  11  False
# 4  38   True

# %% [markdown]
# # Insert new columns with pandas:

# %%
var = pd.DataFrame({"a":[1,2,3,4,5],"b":[9,6,5,4,2]})
print(var)
# Out:
#    a  b
# 0  1  9
# 1  2  6
# 2  3  5
# 3  4  4
# 4  5  2

# %%
var.insert(2,"c",var["a"]) # insert fun.use to add a new col.:.insert(pos. of col.,name_of_col,data to add)must have same elements:

# %%
var
# Out:
#    a  b  c
# 0  1  9  1
# 1  2  6  2
# 2  3  5  3
# 3  4  4  4
# 4  5  2  5

# %%
var.insert(3,"d",[5,6,8,7,3])

# %%
var
# Out:
#    a  b  C  d
# 0  1  9  1  5
# 1  2  6  2  6
# 2  3  5  3  8
# 3  4  4  4  7
# 4  5  2  5  3

# %% [markdown]
# # Copy data from another column:

# %%
var["f"]=var["d"][:4] #create a new column as f and copy all elements from g :used slicing to copy selected elements 0to3:
var
# Out:
#    a  b  C  d    f
# 0  1  9  1  5  5.0
# 1  2  6  2  6  6.0
# 2  3  5  3  8  8.0
# 3  4  4  4  7  7.0
# 4  5  2  5  3  NaN

# %%
# Removing or deleting the columns :

# %%
del var["d"] # del function is use to delete the columns

# %%
var
# Out:
#    a  g  b  C    f
# 0  1  5  9  1  5.0
# 1  2  6  6  2  6.0
# 2  3  8  5  3  8.0
# 3  4  7  4  4  7.0
# 4  5  3  2  5  NaN

# %%
var.pop("f") # pop function will remove the f column: same as del function:
# Out:
# 0    5.0
# 1    6.0
# 2    8.0
# 3    7.0
# 4    NaN
# Name: f, dtype: float64

# %%
var
# Out:
#    a  b  C
# 0  1  9  1
# 1  2  6  2
# 2  3  5  3
# 3  4  4  4
# 4  5  2  5

# %% [markdown]
# # CSV(Comma Seperated Values)

# %%
import pandas as pd
df = pd.DataFrame({"a":[1,2,4,5,6],"b":[8,6,4,4,8],"c":[22,55,447,52,33]})
df
# Out:
#    a  b    c
# 0  1  8   22
# 1  2  6   55
# 2  4  4  447
# 3  5  4   52
# 4  6  8   33

# %%
df.to_csv("Demo1.csv") # to_csv is a function use to convert the data frame into csv file also the file_name must endswith .csv

# %%
#The file saved on the location: C:Users/Tarun: no need to pass the location to save the file:

# %%
df.to_csv("Demo2.csv",index=False) # when you don't want the df indexing as the csv already have it just pass ,index=false:

# %%
df.to_csv("Demo3.csv",index=False,header=["Age","Street","House No:"]) # want to change the column name header=[pass_col_name]:

# %% [markdown]
# # Read and Write operations in CSV:

# %%
jd=pd.read_csv("Demo3.csv") # there is no need to mention the loc as the Demo3.csv file is saved in same location as jupyter:

# %%
jd
# Out:
#    Age  Street  House No:
# 0    1       8         22
# 1    2       6         55
# 2    4       4        447
# 3    5       4         52
# 4    6       8         33

# %%
stu=pd.read_csv("C:\\Users\\Tarun\\Desktop\\Sql\\Stu.csv") #read_csv("Location of csv file")

# %%
stu
# Out:
#    roll_no    name    phone_no  age          address      city  Country
# 0        1   Tarun   958645481   23  shreeji hieghts  Ahmedabad    India
# 1        2  Pratik   845483152   24   govardhan park      Surat    India
# 2        3  Yuvraj   784521585   24  sukhray mahadev    Mehsana    India
# 3        5  Chirag   971450557   24   yogeshwar park  Ahmedabad    India
# 4        6   Vihar  8454215844   26    gopi bunglows     Adalah    India

# %% [markdown]
# # nrows: No of rows to return:

# %%
df=pd.read_csv("C:\\Users\\Tarun\\Desktop\\Sql\\Stu.csv",nrows=3 ) # nrows is use for returning the no of rows from csv file:
df
# Out:
#    roll_no    name   phone_no  age          address      city  Country
# 0        1   Tarun  958645481   23  shreeji hieghts  Ahmedabad    India
# 1        2  Pratik  845483152   24   govardhan park      Surat    India
# 2        3  Yuvraj  784521585   24  sukhray mahadev    Mehsana    India

# %%
df=pd.read_csv("C:\\Users\\Tarun\\Desktop\\Sql\\Stu.csv",nrows=0) # will return the header section from the csv file

# %%
df
# Out:
# Empty DataFrame
# Columns: [roll_no, name, phone_no, age, address, city , Country ]
# Index: []

# %% [markdown]
# # usecols: use columns is use to return the specific columns by their name or their numbers:

# %%
df = pd.read_csv("C:\\Users\\Tarun\\Desktop\\Sql\\Stu.csv",usecols=["name","roll_no"])
df # usecols=["This will return the specified columns from the table"]
# Out:
#    roll_no    name
# 0        1   Tarun
# 1        2  Pratik
# 2        3  Yuvraj
# 3        5  Chirag
# 4        6   Vihar

# %%
df[["name","roll_no"]] # or we can use this way:
# Out:
#      name  roll_no
# 0   Tarun        1
# 1  Pratik        2
# 2  Yuvraj        3
# 3  Chirag        5
# 4   Vihar        6

# %%
df=pd.read_csv("C:\\Users\\Tarun\\Desktop\\Sql\\Stu.csv",usecols=[0,1,5,6])# here we can pass the col_no in place of their name:

# %%
df
# Out:
#    roll_no    name      city  Country
# 0        1   Tarun  Ahmedabad    India
# 1        2  Pratik      Surat    India
# 2        3  Yuvraj    Mehsana    India
# 3        5  Chirag  Ahmedabad    India
# 4        6   Vihar     Adalah    India

# %% [markdown]
# # Skipping rows: per the name it will skip the rows from the csv file :

# %%
df = pd.read_csv("C:\\Users\\Tarun\\Desktop\\Sql\\Stu.csv",skiprows= [2,4])

# %%
df # [0th] heading row is also count so it will skip if mentioned:
# Out:
#    roll_no    name    phone_no  age          address      city  Country
# 0        1   Tarun   958645481   23  shreeji hieghts  Ahmedabad    India
# 1        3  Yuvraj   784521585   24  sukhray mahadev    Mehsana    India
# 2        6   Vihar  8454215844   26    gopi bunglows     Adalah    India

# %% [markdown]
# # indexcol:
# is use to convert the column and their elements into bold:

# %%
df = pd.read_csv("C:\\Users\\Tarun\\Desktop\\Sql\\Stu.csv", index_col=[1,2])

# %%
df
# Out:
#                    roll_no  age          address      city  Country
# name   phone_no
# Tarun  958645481         1   23  shreeji hieghts  Ahmedabad    India
# Pratik 845483152         2   24   govardhan park      Surat    India
# Yuvraj 784521585         3   24  sukhray mahadev    Mehsana    India
# Chirag 971450557         5   24   yogeshwar park  Ahmedabad    India
# Vihar  8454215844        6   26    gopi bunglows     Adalah    India

# %%
df = pd.read_csv("C:\\Users\\Tarun\\Desktop\\Sql\\Stu.csv", index_col="roll_no")

# %%
df
# Out:
#            name    phone_no  age          address      city  Country
# roll_no
# 1         Tarun   958645481   23  shreeji hieghts  Ahmedabad    India
# 2        Pratik   845483152   24   govardhan park      Surat    India
# 3        Yuvraj   784521585   24  sukhray mahadev    Mehsana    India
# 5        Chirag   971450557   24   yogeshwar park  Ahmedabad    India
# 6         Vihar  8454215844   26    gopi bunglows     Adalah    India

# %% [markdown]
# # header:

# %%
df=pd.read_csv("C:\\Users\\Tarun\\Desktop\\Sql\\Stu.csv",header = None) # this will remove the actual header replace with num

# %%
df
# Out:
#          0       1           2    3                4          5         6
# 0  roll_no    name    phone_no  age          address      city   Country
# 1        1   Tarun   958645481   23  shreeji hieghts  Ahmedabad     India
# 2        2  Pratik   845483152   24   govardhan park      Surat     India
# 3        3  Yuvraj   784521585   24  sukhray mahadev    Mehsana     India
# 4        5  Chirag   971450557   24   yogeshwar park  Ahmedabad     India
# 5        6   Vihar  8454215844   26    gopi bunglows     Adalah     India

# %%
df=pd.read_csv("C:\\Users\\Tarun\\Desktop\\Sql\\Stu.csv",header = 1) # this will remove the actual header replace with 1 row

# %%
df
# Out:
#    1   Tarun   958645481  23  shreeji hieghts  Ahmedabad  India
# 0  2  Pratik   845483152  24   govardhan park      Surat  India
# 1  3  Yuvraj   784521585  24  sukhray mahadev    Mehsana  India
# 2  5  Chirag   971450557  24   yogeshwar park  Ahmedabad  India
# 3  6   Vihar  8454215844  26    gopi bunglows     Adalah  India

# %%
df=pd.read_csv("C:\\Users\\Tarun\\Desktop\\Sql\\Stu.csv",names=["col","col1","col2","col3","col4","col5","col6"])

# %%
df # this will change the header's name with given names:
# Out:
#        col    col1        col2 col3             col4       col5      col6
# 0  roll_no    name    phone_no  age          address      city   Country
# 1        1   Tarun   958645481   23  shreeji hieghts  Ahmedabad     India
# 2        2  Pratik   845483152   24   govardhan park      Surat     India
# 3        3  Yuvraj   784521585   24  sukhray mahadev    Mehsana     India
# 4        5  Chirag   971450557   24   yogeshwar park  Ahmedabad     India
# 5        6   Vihar  8454215844   26    gopi bunglows     Adalah     India

# %%
df=pd.read_csv("C:\\Users\\Tarun\\Desktop\\Sql\\Stu.csv",dtype={"age":float}) # to change the datatype:

# %%
df
# Out:
#    roll_no    name    phone_no   age          address      city  Country
# 0        1   Tarun   958645481  23.0  shreeji hieghts  Ahmedabad    India
# 1        2  Pratik   845483152  24.0   govardhan park      Surat    India
# 2        3  Yuvraj   784521585  24.0  sukhray mahadev    Mehsana    India
# 3        5  Chirag   971450557  24.0   yogeshwar park  Ahmedabad    India
# 4        6   Vihar  8454215844  26.0    gopi bunglows     Adalah    India

# %%
stu = pd.read_csv("C:\\Users\\Tarun\\Desktop\\Sql\\Stu.csv",header = None)

# %%
stu
# Out:
#          0       1           2    3                4          5         6
# 0  roll_no    name    phone_no  age          address      city   Country
# 1        1   Tarun   958645481   23  shreeji hieghts  Ahmedabad     India
# 2        2  Pratik   845483152   24   govardhan park      Surat     India
# 3        3  Yuvraj   784521585   24  sukhray mahadev    Mehsana     India
# 4        5  Chirag   971450557   24   yogeshwar park  Ahmedabad     India
# 5        6   Vihar  8454215844   26    gopi bunglows     Adalah     India

# %%
stu.add_prefix("col") # when you want to add prefix to the column header:
# Out:
#       col0    col1        col2 col3             col4       col5      col6
# 0  roll_no    name    phone_no  age          address      city   Country
# 1        1   Tarun   958645481   23  shreeji hieghts  Ahmedabad     India
# 2        2  Pratik   845483152   24   govardhan park      Surat     India
# 3        3  Yuvraj   784521585   24  sukhray mahadev    Mehsana     India
# 4        5  Chirag   971450557   24   yogeshwar park  Ahmedabad     India
# 5        6   Vihar  8454215844   26    gopi bunglows     Adalah     India
